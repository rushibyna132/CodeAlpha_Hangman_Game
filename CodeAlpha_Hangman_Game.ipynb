# %% [markdown]
# <a href="https://colab.research.google.com/github/rushibyna132/CodeAlpha_Hangman_Game/blob/main/CodeAlpha_Hangman_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# List of words
words = ["python", "coding", "computer", "program", "developer"]

print("🎮 Welcome to Hangman!")

while True:

    # Choose a random word
    word = random.choice(words)

    guessed_letters = []
    wrong_guesses = 0
    max_wrong_guesses = 6

    print("\nLet's start the game!")

    while wrong_guesses < max_wrong_guesses:

        # Display the word
        display_word = ""

        for letter in word:
            if letter in guessed_letters:
                display_word += letter + " "
            else:
                display_word += "_ "

        print("\nWord:", display_word)
        print("Guessed letters:", ", ".join(guessed_letters))
        print("Wrong guesses:", wrong_guesses)

        # Get the player's guess
        guess = input("Guess a letter: ").lower()

        # Check if input is valid
        if len(guess) != 1 or not guess.isalpha():
            print("Please enter only one letter!")
            continue

        # Check for repeated guess
        if guess in guessed_letters:
            print("You already guessed that letter!")
            continue

        # Add the guess
        guessed_letters.append(guess)

        # Check the guess
        if guess in word:
            print("Correct guess!")
        else:
            wrong_guesses += 1
            print("Wrong guess!")

        # Check if the player won
        if all(letter in guessed_letters for letter in word):
            print("\n🎉 You won!")
            print("The word was:", word)
            break

    # Check if the player lost
    if wrong_guesses == max_wrong_guesses:
        print("\n💀 Game over!")
        print("The word was:", word)

    # Ask to play again
    play_again = input("\nDo you want to play again? (yes/no): ").lower()

    if play_again != "yes":
        print("\nThanks for playing Hangman! 👋")
        break
# Out:
# 🎮 Welcome to Hangman!
#
# Let's start the game!
#
# Word: _ _ _ _ _ _
# Guessed letters:
# Wrong guesses: 0
# Guess a letter: C
# Wrong guess!
#
# Word: _ _ _ _ _ _
# Guessed letters: c
# Wrong guesses: 1
# Guess a letter: P
# Correct guess!
#
# Word: p _ _ _ _ _
# Guessed letters: c, p
# Wrong guesses: 1
# Guess a letter: X
# Wrong guess!
#
# Word: p _ _ _ _ _
# Guessed letters: c, p, x
# Wrong guesses: 2
# Guess a letter: R
# Wrong guess!
#
# Word: p _ _ _ _ _
# Guessed letters: c, p, x, r
# Wrong guesses: 3
# Guess a letter: Y
# Correct guess!
#
# Word: p y _ _ _ _
# Guessed letters: c, p, x, r, y
# Wrong guesses: 3
# Guess a letter: T
# Correct guess!
#
# Word: p y t _ _ _
# Guessed letters: c, p, x, r, y, t
# Wrong guesses: 3
# Guess a letter: H
# Correct guess!
#
# Word: p y t h _ _
# Guessed letters: c, p, x, r, y, t, h
# Wrong guesses: 3
# Guess a letter: M
# Wrong guess!
#
# Word: p y t h _ _
# Guessed letters: c, p, x, r, y, t, h, m
# Wrong guesses: 4
# Guess a letter: D
# ...
